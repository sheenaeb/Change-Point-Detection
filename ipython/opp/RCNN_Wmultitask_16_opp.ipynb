# %%
# useing this variable for saving models and summaries
exp_name = "RCNN_Wmultitask_16_opp"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../../src')

# %%
import models.CNN_lstm_model as CNN_lstm_model
import training
import evaluation.nn_eval_multitask as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../data/opp8.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((691, 1024, 77), (691, 1024, 19))

# %%
test_data.shape, test_gt.shape
# Out:
# ((119, 1024, 77), (119, 1024, 19))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 100

pooling_stride = [4, 2, 2]
weights_shape = [[9, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
activation = tf.nn.relu

lstm_n_hidden = 128
n_classes = 19

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)

pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)

variables_weights = np.ones((n_classes,))

# %%
pos_weight.shape
# Out:
# (19,)

# %%
pos_weight
# Out:
# array([  0.36565482,  48.46756152,  47.65126513,  50.0669746 ,
#         49.94930876,  40.02411874,  41.52307692,  58.84303112,
#         63.4664723 ,  75.37996546,  86.74603175,  80.14495413,
#         87.27145709,  69.42038217,  68.86413902,  43.71587462,
#         13.05721551,  58.2021419 ,  10.05323669])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../summary/' + exp_name 
checkpoint_path = '../../model/' + exp_name + '/' + exp_name

# %%
model = CNN_lstm_model.Model(n_variables = n_variables,
                        n_classes = n_classes)

# %%
model.build_cnn_lstm_net(pooling_stride = pooling_stride,
                         weights_shape = weights_shape,
                         bias_shape = bias_shape,
                         activation = activation,
                         lstm_n_hidden = lstm_n_hidden,
                         n_classes = n_classes,
                         learning_rate = learning_rate,
                         pos_weight = pos_weight,
                         trainable_conv = True,
                         trainable_last = True,
                         variables_weights = variables_weights)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'multitask')

# %%
trainer.train(max_iter = 20000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.065 vs. 0.064
# F1 = 0.103 vs. 0.099
# Accuracy = 0.014 vs. 0.056
# CHANGE DETECTION
# AUC = 0.080 vs. 0.099
# F1 = 0.192 vs. 0.183
# Precision = 0.108 vs. 0.101
# Recall = 0.907 vs. 0.953
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.061 vs. 0.060
# F1 = 0.088 vs. 0.087
# Accuracy = 0.012 vs. 0.056
# CHANGE DETECTION
# AUC = 0.036 vs. 0.048
# F1 = 0.103 vs. 0.099
# Precision = 0.055 vs. 0.052
# Recall = 0.958 vs. 0.961
# Minibatch Loss= 2.329664
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.711 vs. 0.061
# F1 = 0.693 vs. 0.093
# Accuracy = 0.648 vs. 0.056
# CHANGE DETECTION
# AUC = 0.258 vs. 0.094
# F1 = 0.340 vs. 0.179
# Precision = 0.260 vs. 0.099
# Recall = 0.491 vs. 0.929
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.427 vs. 0.059
# F1 = 0.486 vs. 0.081
# Accuracy = 0.612 vs. 0.056
# CHANGE DETECTION
# AUC = 0.186 vs. 0.050
# F1 = 0.278 vs. 0.097
# Precision = 0.199 vs. 0.051
# Recall = 0.460 vs. 1.000
# Minibatch Loss= 0.284235
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.817 vs. 0.061
# F1 = 0.780 vs. 0.089
# Accuracy = 0.772 vs. 0.056
# CHANGE DETECTION
# AUC = 0.436 vs. 0.094
# F1 = 0.468 vs. 0.173
# Precision = 0.413 vs. 0.095
# Recall = 0.541 vs. 0.925
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.514 vs. 0.059
# F1 = 0.555 vs. 0.082
# Accuracy = 0.751 vs. 0.056
# CHANGE DETECTION
# AUC = 0.217 vs. 0.054
# F1 = 0.311 vs. 0.101
# Precision = 0.221 vs. 0.054
# Recall = 0.525 vs. 0.823
# Minibatch Loss= 0.158685
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.866 vs. 0.060
# F1 = 0.822 vs. 0.087
# Accuracy = 0.848 vs. 0.056
# CHANGE DETECTION
# AUC = 0.481 vs. 0.086
# F1 = 0.508 vs. 0.154
# Precision = 0.432 vs. 0.083
# Recall = 0.616 vs. 0.985
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.572 vs. 0.060
# F1 = 0.589 vs. 0.078
# Accuracy = 0.806 vs. 0.056
# CHANGE DETECTION
# AUC = 0.237 vs. 0.052
# F1 = 0.319 vs. 0.098
# Precision = 0.221 vs. 0.054
# Recall = 0.569 vs. 0.608
# Minibatch Loss= 0.125668
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.919 vs. 0.062
# F1 = 0.876 vs. 0.094
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.505 vs. 0.106
# F1 = 0.538 vs. 0.184
# Precision = 0.453 vs. 0.103
# Recall = 0.664 vs. 0.889
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.616 vs. 0.059
# F1 = 0.624 vs. 0.082
# Accuracy = 0.842 vs. 0.056
# CHANGE DETECTION
# AUC = 0.245 vs. 0.049
# F1 = 0.328 vs. 0.096
# Precision = 0.239 vs. 0.051
# Recall = 0.519 vs. 1.000
# Minibatch Loss= 0.104389
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.943 vs. 0.062
# F1 = 0.899 vs. 0.091
# Accuracy = 0.925 vs. 0.056
# CHANGE DETECTION
# AUC = 0.588 vs. 0.107
# F1 = 0.599 vs. 0.195
# Precision = 0.494 vs. 0.109
# Recall = 0.761 vs. 0.939
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.617 vs. 0.058
# F1 = 0.628 vs. 0.078
# Accuracy = 0.863 vs. 0.056
# CHANGE DETECTION
# AUC = 0.256 vs. 0.049
# F1 = 0.347 vs. 0.097
# Precision = 0.260 vs. 0.051
# Recall = 0.522 vs. 0.979
# Minibatch Loss= 0.089246
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.876 vs. 0.062
# F1 = 0.820 vs. 0.090
# Accuracy = 0.870 vs. 0.056
# CHANGE DETECTION
# AUC = 0.468 vs. 0.083
# F1 = 0.518 vs. 0.162
# Precision = 0.424 vs. 0.088
# Recall = 0.667 vs. 0.982
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.581 vs. 0.059
# F1 = 0.594 vs. 0.080
# Accuracy = 0.837 vs. 0.056
# CHANGE DETECTION
# AUC = 0.231 vs. 0.052
# F1 = 0.321 vs. 0.099
# Precision = 0.238 vs. 0.055
# Recall = 0.491 vs. 0.527
# Minibatch Loss= 0.132929
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.920 vs. 0.062
# F1 = 0.872 vs. 0.090
# Accuracy = 0.872 vs. 0.056
# CHANGE DETECTION
# AUC = 0.482 vs. 0.073
# F1 = 0.534 vs. 0.138
# Precision = 0.424 vs. 0.074
# Recall = 0.719 vs. 0.983
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.618 vs. 0.059
# F1 = 0.627 vs. 0.080
# Accuracy = 0.769 vs. 0.056
# CHANGE DETECTION
# AUC = 0.247 vs. 0.054
# F1 = 0.341 vs. 0.097
# Precision = 0.247 vs. 0.051
# Recall = 0.548 vs. 0.927
# Minibatch Loss= 0.089057
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.938 vs. 0.062
# F1 = 0.889 vs. 0.091
# Accuracy = 0.900 vs. 0.056
# CHANGE DETECTION
# AUC = 0.552 vs. 0.080
# F1 = 0.570 vs. 0.147
# Precision = 0.472 vs. 0.080
# Recall = 0.719 vs. 0.915
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.633 vs. 0.058
# F1 = 0.638 vs. 0.080
# Accuracy = 0.853 vs. 0.056
# CHANGE DETECTION
# AUC = 0.260 vs. 0.048
# F1 = 0.349 vs. 0.097
# Precision = 0.248 vs. 0.051
# Recall = 0.592 vs. 0.997
# Minibatch Loss= 0.074632
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.945 vs. 0.061
# F1 = 0.903 vs. 0.089
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.620 vs. 0.076
# F1 = 0.617 vs. 0.159
# Precision = 0.509 vs. 0.086
# Recall = 0.782 vs. 0.985
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.634 vs. 0.059
# F1 = 0.639 vs. 0.082
# Accuracy = 0.822 vs. 0.056
# CHANGE DETECTION
# AUC = 0.263 vs. 0.050
# F1 = 0.345 vs. 0.097
# Precision = 0.265 vs. 0.051
# Recall = 0.494 vs. 0.997
# Minibatch Loss= 0.065019
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.962 vs. 0.062
# F1 = 0.918 vs. 0.094
# Accuracy = 0.922 vs. 0.056
# CHANGE DETECTION
# AUC = 0.620 vs. 0.096
# F1 = 0.605 vs. 0.167
# Precision = 0.516 vs. 0.092
# Recall = 0.731 vs. 0.935
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.642 vs. 0.059
# F1 = 0.646 vs. 0.081
# Accuracy = 0.850 vs. 0.056
# CHANGE DETECTION
# AUC = 0.268 vs. 0.047
# F1 = 0.358 vs. 0.097
# Precision = 0.261 vs. 0.051
# Recall = 0.569 vs. 0.995
# Minibatch Loss= 0.065193
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.965 vs. 0.061
# F1 = 0.924 vs. 0.090
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.594 vs. 0.092
# F1 = 0.615 vs. 0.166
# Precision = 0.499 vs. 0.091
# Recall = 0.802 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.644 vs. 0.060
# F1 = 0.644 vs. 0.085
# Accuracy = 0.844 vs. 0.056
# CHANGE DETECTION
# AUC = 0.273 vs. 0.055
# F1 = 0.353 vs. 0.102
# Precision = 0.245 vs. 0.058
# Recall = 0.629 vs. 0.423
# Minibatch Loss= 0.060078
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.973 vs. 0.060
# F1 = 0.941 vs. 0.088
# Accuracy = 0.932 vs. 0.056
# CHANGE DETECTION
# AUC = 0.657 vs. 0.087
# F1 = 0.643 vs. 0.153
# Precision = 0.525 vs. 0.086
# Recall = 0.830 vs. 0.728
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.649 vs. 0.059
# F1 = 0.649 vs. 0.084
# Accuracy = 0.854 vs. 0.056
# CHANGE DETECTION
# AUC = 0.278 vs. 0.055
# F1 = 0.354 vs. 0.101
# Precision = 0.264 vs. 0.055
# Recall = 0.535 vs. 0.670
# Minibatch Loss= 0.051224
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.980 vs. 0.062
# F1 = 0.950 vs. 0.095
# Accuracy = 0.940 vs. 0.056
# CHANGE DETECTION
# AUC = 0.700 vs. 0.104
# F1 = 0.686 vs. 0.189
# Precision = 0.601 vs. 0.105
# Recall = 0.800 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.643 vs. 0.060
# F1 = 0.642 vs. 0.086
# Accuracy = 0.830 vs. 0.056
# CHANGE DETECTION
# AUC = 0.271 vs. 0.051
# F1 = 0.356 vs. 0.097
# Precision = 0.257 vs. 0.051
# Recall = 0.577 vs. 0.984
# Minibatch Loss= 0.054359
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.986 vs. 0.062
# F1 = 0.963 vs. 0.094
# Accuracy = 0.968 vs. 0.056
# CHANGE DETECTION
# AUC = 0.678 vs. 0.113
# F1 = 0.682 vs. 0.184
# Precision = 0.567 vs. 0.102
# Recall = 0.856 vs. 0.944
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.646 vs. 0.059
# F1 = 0.648 vs. 0.081
# Accuracy = 0.863 vs. 0.056
# CHANGE DETECTION
# AUC = 0.283 vs. 0.051
# F1 = 0.362 vs. 0.098
# Precision = 0.249 vs. 0.052
# Recall = 0.665 vs. 0.761
# Minibatch Loss= 0.049706
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.985 vs. 0.063
# F1 = 0.961 vs. 0.093
# Accuracy = 0.967 vs. 0.056
# CHANGE DETECTION
# AUC = 0.750 vs. 0.107
# F1 = 0.732 vs. 0.179
# Precision = 0.623 vs. 0.099
# Recall = 0.887 vs. 0.942
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.640 vs. 0.059
# F1 = 0.641 vs. 0.083
# Accuracy = 0.853 vs. 0.056
# CHANGE DETECTION
# AUC = 0.279 vs. 0.050
# F1 = 0.366 vs. 0.101
# Precision = 0.267 vs. 0.054
# Recall = 0.579 vs. 0.813
# Minibatch Loss= 0.041247
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.061
# F1 = 0.974 vs. 0.092
# Accuracy = 0.976 vs. 0.056
# CHANGE DETECTION
# AUC = 0.743 vs. 0.096
# F1 = 0.740 vs. 0.168
# Precision = 0.628 vs. 0.092
# Recall = 0.902 vs. 0.966
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.644 vs. 0.058
# F1 = 0.650 vs. 0.080
# Accuracy = 0.865 vs. 0.056
# CHANGE DETECTION
# AUC = 0.279 vs. 0.053
# F1 = 0.364 vs. 0.097
# Precision = 0.270 vs. 0.051
# Recall = 0.558 vs. 0.997
# Minibatch Loss= 0.036473
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.988 vs. 0.061
# F1 = 0.964 vs. 0.092
# Accuracy = 0.939 vs. 0.056
# CHANGE DETECTION
# AUC = 0.744 vs. 0.094
# F1 = 0.727 vs. 0.177
# Precision = 0.659 vs. 0.097
# Recall = 0.812 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.637 vs. 0.059
# F1 = 0.648 vs. 0.081
# Accuracy = 0.809 vs. 0.056
# CHANGE DETECTION
# AUC = 0.268 vs. 0.051
# F1 = 0.333 vs. 0.099
# Precision = 0.239 vs. 0.053
# Recall = 0.553 vs. 0.888
# Minibatch Loss= 0.045557
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.986 vs. 0.061
# F1 = 0.957 vs. 0.091
# Accuracy = 0.948 vs. 0.056
# CHANGE DETECTION
# AUC = 0.739 vs. 0.095
# F1 = 0.722 vs. 0.172
# Precision = 0.634 vs. 0.094
# Recall = 0.838 vs. 0.972
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.666 vs. 0.059
# F1 = 0.671 vs. 0.081
# Accuracy = 0.854 vs. 0.056
# CHANGE DETECTION
# AUC = 0.296 vs. 0.053
# F1 = 0.378 vs. 0.096
# Precision = 0.280 vs. 0.051
# Recall = 0.584 vs. 0.997
# Minibatch Loss= 0.043143
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.061
# F1 = 0.975 vs. 0.092
# Accuracy = 0.967 vs. 0.056
# CHANGE DETECTION
# AUC = 0.823 vs. 0.092
# F1 = 0.768 vs. 0.170
# Precision = 0.669 vs. 0.093
# Recall = 0.901 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.656 vs. 0.059
# F1 = 0.656 vs. 0.080
# Accuracy = 0.868 vs. 0.056
# CHANGE DETECTION
# AUC = 0.282 vs. 0.051
# F1 = 0.367 vs. 0.097
# Precision = 0.263 vs. 0.052
# Recall = 0.610 vs. 0.826
# Minibatch Loss= 0.031902
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.061
# F1 = 0.977 vs. 0.091
# Accuracy = 0.976 vs. 0.056
# CHANGE DETECTION
# AUC = 0.820 vs. 0.098
# F1 = 0.787 vs. 0.163
# Precision = 0.710 vs. 0.089
# Recall = 0.881 vs. 0.989
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.651 vs. 0.059
# F1 = 0.656 vs. 0.081
# Accuracy = 0.865 vs. 0.056
# CHANGE DETECTION
# AUC = 0.279 vs. 0.051
# F1 = 0.357 vs. 0.097
# Precision = 0.292 vs. 0.052
# Recall = 0.460 vs. 0.745
# Minibatch Loss= 0.027606
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.061
# F1 = 0.977 vs. 0.090
# Accuracy = 0.974 vs. 0.056
# CHANGE DETECTION
# AUC = 0.768 vs. 0.071
# F1 = 0.766 vs. 0.139
# Precision = 0.696 vs. 0.076
# Recall = 0.851 vs. 0.877
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.646 vs. 0.058
# F1 = 0.654 vs. 0.081
# Accuracy = 0.863 vs. 0.056
# CHANGE DETECTION
# AUC = 0.275 vs. 0.052
# F1 = 0.348 vs. 0.098
# Precision = 0.243 vs. 0.052
# Recall = 0.610 vs. 0.784
# Minibatch Loss= 0.025259
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.060
# F1 = 0.986 vs. 0.089
# Accuracy = 0.978 vs. 0.056
# CHANGE DETECTION
# AUC = 0.871 vs. 0.082
# F1 = 0.831 vs. 0.155
# Precision = 0.769 vs. 0.084
# Recall = 0.904 vs. 0.944
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.640 vs. 0.060
# F1 = 0.653 vs. 0.080
# Accuracy = 0.865 vs. 0.056
# CHANGE DETECTION
# AUC = 0.271 vs. 0.049
# F1 = 0.343 vs. 0.097
# Precision = 0.245 vs. 0.051
# Recall = 0.571 vs. 0.992
# Minibatch Loss= 0.022916
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.060
# F1 = 0.987 vs. 0.091
# Accuracy = 0.974 vs. 0.056
# CHANGE DETECTION
# AUC = 0.866 vs. 0.095
# F1 = 0.848 vs. 0.175
# Precision = 0.769 vs. 0.096
# Recall = 0.945 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.637 vs. 0.059
# F1 = 0.649 vs. 0.081
# Accuracy = 0.868 vs. 0.056
# CHANGE DETECTION
# AUC = 0.271 vs. 0.048
# F1 = 0.340 vs. 0.097
# Precision = 0.292 vs. 0.051
# Recall = 0.408 vs. 1.000
# Minibatch Loss= 0.024410
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.061
# F1 = 0.987 vs. 0.090
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 0.874 vs. 0.095
# F1 = 0.839 vs. 0.174
# Precision = 0.764 vs. 0.095
# Recall = 0.931 vs. 0.982
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.634 vs. 0.059
# F1 = 0.649 vs. 0.082
# Accuracy = 0.868 vs. 0.056
# CHANGE DETECTION
# AUC = 0.269 vs. 0.059
# F1 = 0.343 vs. 0.106
# Precision = 0.293 vs. 0.063
# Recall = 0.413 vs. 0.325
# Minibatch Loss= 0.022678
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.062
# F1 = 0.986 vs. 0.096
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.894 vs. 0.106
# F1 = 0.854 vs. 0.185
# Precision = 0.823 vs. 0.102
# Recall = 0.888 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.630 vs. 0.059
# F1 = 0.642 vs. 0.081
# Accuracy = 0.868 vs. 0.056
# CHANGE DETECTION
# AUC = 0.266 vs. 0.052
# F1 = 0.338 vs. 0.098
# Precision = 0.280 vs. 0.052
# Recall = 0.429 vs. 0.961
# Minibatch Loss= 0.023784
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.955 vs. 0.062
# F1 = 0.906 vs. 0.093
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.713 vs. 0.098
# F1 = 0.696 vs. 0.178
# Precision = 0.602 vs. 0.098
# Recall = 0.825 vs. 0.987
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.627 vs. 0.059
# F1 = 0.633 vs. 0.081
# Accuracy = 0.846 vs. 0.056
# CHANGE DETECTION
# AUC = 0.254 vs. 0.052
# F1 = 0.357 vs. 0.099
# Precision = 0.289 vs. 0.053
# Recall = 0.468 vs. 0.753
# Minibatch Loss= 0.112881
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.061
# F1 = 0.984 vs. 0.088
# Accuracy = 0.974 vs. 0.056
# CHANGE DETECTION
# AUC = 0.882 vs. 0.076
# F1 = 0.850 vs. 0.147
# Precision = 0.806 vs. 0.079
# Recall = 0.899 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.678 vs. 0.058
# F1 = 0.677 vs. 0.079
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.291 vs. 0.051
# F1 = 0.365 vs. 0.099
# Precision = 0.272 vs. 0.052
# Recall = 0.556 vs. 0.865
# Minibatch Loss= 0.019704
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.061
# F1 = 0.988 vs. 0.090
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.889 vs. 0.086
# F1 = 0.864 vs. 0.162
# Precision = 0.792 vs. 0.088
# Recall = 0.951 vs. 0.973
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.658 vs. 0.058
# F1 = 0.667 vs. 0.079
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.278 vs. 0.049
# F1 = 0.357 vs. 0.097
# Precision = 0.293 vs. 0.051
# Recall = 0.457 vs. 0.956
# Minibatch Loss= 0.018698
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.060
# F1 = 0.993 vs. 0.089
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.914 vs. 0.082
# F1 = 0.894 vs. 0.149
# Precision = 0.843 vs. 0.081
# Recall = 0.953 vs. 0.937
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.651 vs. 0.059
# F1 = 0.663 vs. 0.080
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.268 vs. 0.048
# F1 = 0.354 vs. 0.097
# Precision = 0.278 vs. 0.051
# Recall = 0.486 vs. 0.992
# Minibatch Loss= 0.015513
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.060
# F1 = 0.992 vs. 0.090
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.929 vs. 0.090
# F1 = 0.914 vs. 0.167
# Precision = 0.858 vs. 0.091
# Recall = 0.978 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.644 vs. 0.058
# F1 = 0.656 vs. 0.078
# Accuracy = 0.878 vs. 0.056
# CHANGE DETECTION
# AUC = 0.266 vs. 0.050
# F1 = 0.351 vs. 0.097
# Precision = 0.274 vs. 0.051
# Recall = 0.488 vs. 0.961
# Minibatch Loss= 0.015666
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.061
# F1 = 0.993 vs. 0.089
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.889 vs. 0.083
# F1 = 0.899 vs. 0.151
# Precision = 0.838 vs. 0.082
# Recall = 0.968 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.639 vs. 0.058
# F1 = 0.652 vs. 0.080
# Accuracy = 0.880 vs. 0.056
# CHANGE DETECTION
# AUC = 0.262 vs. 0.055
# F1 = 0.341 vs. 0.099
# Precision = 0.286 vs. 0.056
# Recall = 0.423 vs. 0.416
# Minibatch Loss= 0.015167
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.995 vs. 0.093
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.951 vs. 0.099
# F1 = 0.933 vs. 0.193
# Precision = 0.890 vs. 0.107
# Recall = 0.979 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.637 vs. 0.059
# F1 = 0.650 vs. 0.081
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.257 vs. 0.054
# F1 = 0.337 vs. 0.099
# Precision = 0.270 vs. 0.052
# Recall = 0.449 vs. 0.829
# Minibatch Loss= 0.015054
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.994 vs. 0.094
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.951 vs. 0.099
# F1 = 0.941 vs. 0.173
# Precision = 0.904 vs. 0.096
# Recall = 0.982 vs. 0.937
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.636 vs. 0.058
# F1 = 0.644 vs. 0.080
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.254 vs. 0.049
# F1 = 0.330 vs. 0.098
# Precision = 0.265 vs. 0.052
# Recall = 0.436 vs. 0.927
# Minibatch Loss= 0.012941
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.980 vs. 0.061
# F1 = 0.945 vs. 0.089
# Accuracy = 0.931 vs. 0.056
# CHANGE DETECTION
# AUC = 0.820 vs. 0.085
# F1 = 0.769 vs. 0.160
# Precision = 0.711 vs. 0.087
# Recall = 0.837 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.648 vs. 0.059
# F1 = 0.661 vs. 0.081
# Accuracy = 0.794 vs. 0.056
# CHANGE DETECTION
# AUC = 0.239 vs. 0.055
# F1 = 0.337 vs. 0.101
# Precision = 0.246 vs. 0.060
# Recall = 0.532 vs. 0.335
# Minibatch Loss= 0.064405
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.063
# F1 = 0.991 vs. 0.096
# Accuracy = 0.984 vs. 0.056
# CHANGE DETECTION
# AUC = 0.953 vs. 0.103
# F1 = 0.930 vs. 0.191
# Precision = 0.899 vs. 0.106
# Recall = 0.963 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.648 vs. 0.059
# F1 = 0.658 vs. 0.080
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.266 vs. 0.052
# F1 = 0.344 vs. 0.096
# Precision = 0.276 vs. 0.051
# Recall = 0.455 vs. 1.000
# Minibatch Loss= 0.016221
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.997 vs. 0.089
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.970 vs. 0.088
# F1 = 0.943 vs. 0.165
# Precision = 0.923 vs. 0.090
# Recall = 0.964 vs. 0.968
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.637 vs. 0.058
# F1 = 0.649 vs. 0.077
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.261 vs. 0.051
# F1 = 0.340 vs. 0.099
# Precision = 0.265 vs. 0.052
# Recall = 0.475 vs. 0.974
# Minibatch Loss= 0.010342
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.059
# F1 = 0.997 vs. 0.087
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.982 vs. 0.084
# F1 = 0.963 vs. 0.161
# Precision = 0.932 vs. 0.088
# Recall = 0.996 vs. 0.960
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.631 vs. 0.059
# F1 = 0.642 vs. 0.080
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.253 vs. 0.052
# F1 = 0.330 vs. 0.099
# Precision = 0.248 vs. 0.053
# Recall = 0.491 vs. 0.795
# Minibatch Loss= 0.009334
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 0.998 vs. 0.097
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.982 vs. 0.101
# F1 = 0.964 vs. 0.188
# Precision = 0.941 vs. 0.104
# Recall = 0.988 vs. 0.962
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.633 vs. 0.058
# F1 = 0.644 vs. 0.080
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.255 vs. 0.052
# F1 = 0.332 vs. 0.098
# Precision = 0.250 vs. 0.052
# Recall = 0.496 vs. 0.888
# Minibatch Loss= 0.010388
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.998 vs. 0.092
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.985 vs. 0.098
# F1 = 0.967 vs. 0.175
# Precision = 0.940 vs. 0.096
# Recall = 0.995 vs. 0.953
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.629 vs. 0.060
# F1 = 0.640 vs. 0.082
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.248 vs. 0.051
# F1 = 0.317 vs. 0.097
# Precision = 0.250 vs. 0.052
# Recall = 0.434 vs. 0.800
# Minibatch Loss= 0.008975
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.998 vs. 0.092
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.987 vs. 0.099
# F1 = 0.974 vs. 0.175
# Precision = 0.957 vs. 0.097
# Recall = 0.992 vs. 0.877
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.630 vs. 0.059
# F1 = 0.644 vs. 0.080
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.252 vs. 0.053
# F1 = 0.322 vs. 0.099
# Precision = 0.242 vs. 0.060
# Recall = 0.481 vs. 0.291
# Minibatch Loss= 0.008327
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.998 vs. 0.092
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.982 vs. 0.075
# F1 = 0.979 vs. 0.148
# Precision = 0.961 vs. 0.081
# Recall = 0.998 vs. 0.943
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.628 vs. 0.059
# F1 = 0.640 vs. 0.081
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.250 vs. 0.049
# F1 = 0.325 vs. 0.096
# Precision = 0.237 vs. 0.051
# Recall = 0.519 vs. 1.000
# Minibatch Loss= 0.006416
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.096
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.994 vs. 0.095
# F1 = 0.989 vs. 0.174
# Precision = 0.979 vs. 0.095
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.627 vs. 0.058
# F1 = 0.639 vs. 0.080
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.249 vs. 0.049
# F1 = 0.320 vs. 0.098
# Precision = 0.268 vs. 0.052
# Recall = 0.397 vs. 0.956
# Minibatch Loss= 0.006520
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.967 vs. 0.061
# F1 = 0.918 vs. 0.092
# Accuracy = 0.945 vs. 0.056
# CHANGE DETECTION
# AUC = 0.744 vs. 0.092
# F1 = 0.701 vs. 0.167
# Precision = 0.697 vs. 0.092
# Recall = 0.705 vs. 0.938
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.642 vs. 0.059
# F1 = 0.642 vs. 0.081
# Accuracy = 0.854 vs. 0.056
# CHANGE DETECTION
# AUC = 0.283 vs. 0.054
# F1 = 0.378 vs. 0.100
# Precision = 0.289 vs. 0.053
# Recall = 0.545 vs. 0.834
# Minibatch Loss= 0.064797
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.061
# F1 = 0.974 vs. 0.089
# Accuracy = 0.973 vs. 0.056
# CHANGE DETECTION
# AUC = 0.910 vs. 0.094
# F1 = 0.824 vs. 0.174
# Precision = 0.788 vs. 0.096
# Recall = 0.863 vs. 0.954
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.706 vs. 0.058
# F1 = 0.696 vs. 0.080
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.312 vs. 0.049
# F1 = 0.387 vs. 0.097
# Precision = 0.291 vs. 0.051
# Recall = 0.579 vs. 0.964
# Minibatch Loss= 0.027874
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.061
# F1 = 0.989 vs. 0.092
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.949 vs. 0.099
# F1 = 0.902 vs. 0.181
# Precision = 0.858 vs. 0.100
# Recall = 0.952 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.705 vs. 0.058
# F1 = 0.695 vs. 0.080
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.052
# F1 = 0.378 vs. 0.099
# Precision = 0.348 vs. 0.054
# Recall = 0.413 vs. 0.582
# Minibatch Loss= 0.018546
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.995 vs. 0.090
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.963 vs. 0.079
# F1 = 0.922 vs. 0.142
# Precision = 0.864 vs. 0.077
# Recall = 0.990 vs. 0.933
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.693 vs. 0.058
# F1 = 0.686 vs. 0.077
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.293 vs. 0.050
# F1 = 0.365 vs. 0.097
# Precision = 0.319 vs. 0.051
# Recall = 0.429 vs. 1.000
# Minibatch Loss= 0.011477
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.996 vs. 0.090
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.968 vs. 0.090
# F1 = 0.942 vs. 0.169
# Precision = 0.926 vs. 0.092
# Recall = 0.958 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.685 vs. 0.058
# F1 = 0.683 vs. 0.079
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.292 vs. 0.053
# F1 = 0.367 vs. 0.099
# Precision = 0.295 vs. 0.053
# Recall = 0.483 vs. 0.774
# Minibatch Loss= 0.011287
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.997 vs. 0.090
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.982 vs. 0.096
# F1 = 0.962 vs. 0.173
# Precision = 0.949 vs. 0.095
# Recall = 0.977 vs. 0.978
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.678 vs. 0.058
# F1 = 0.675 vs. 0.083
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.285 vs. 0.051
# F1 = 0.352 vs. 0.097
# Precision = 0.275 vs. 0.054
# Recall = 0.491 vs. 0.465
# Minibatch Loss= 0.009069
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.997 vs. 0.091
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.984 vs. 0.097
# F1 = 0.969 vs. 0.166
# Precision = 0.953 vs. 0.094
# Recall = 0.986 vs. 0.687
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.667 vs. 0.058
# F1 = 0.672 vs. 0.081
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.280 vs. 0.050
# F1 = 0.345 vs. 0.099
# Precision = 0.274 vs. 0.055
# Recall = 0.468 vs. 0.481
# Minibatch Loss= 0.008142
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.998 vs. 0.091
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.992 vs. 0.087
# F1 = 0.981 vs. 0.166
# Precision = 0.966 vs. 0.090
# Recall = 0.997 vs. 0.981
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.661 vs. 0.059
# F1 = 0.672 vs. 0.084
# Accuracy = 0.898 vs. 0.056
# CHANGE DETECTION
# AUC = 0.279 vs. 0.053
# F1 = 0.346 vs. 0.097
# Precision = 0.282 vs. 0.051
# Recall = 0.447 vs. 0.997
# Minibatch Loss= 0.006507
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.998 vs. 0.090
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.990 vs. 0.094
# F1 = 0.982 vs. 0.169
# Precision = 0.967 vs. 0.092
# Recall = 0.997 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.656 vs. 0.060
# F1 = 0.665 vs. 0.084
# Accuracy = 0.899 vs. 0.056
# CHANGE DETECTION
# AUC = 0.276 vs. 0.049
# F1 = 0.344 vs. 0.096
# Precision = 0.271 vs. 0.051
# Recall = 0.473 vs. 1.000
# Minibatch Loss= 0.006518
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.089
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.992 vs. 0.094
# F1 = 0.983 vs. 0.167
# Precision = 0.972 vs. 0.092
# Recall = 0.994 vs. 0.958
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.654 vs. 0.059
# F1 = 0.668 vs. 0.079
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.273 vs. 0.051
# F1 = 0.336 vs. 0.097
# Precision = 0.252 vs. 0.051
# Recall = 0.504 vs. 0.997
# Minibatch Loss= 0.006132
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.998 vs. 0.089
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.996 vs. 0.090
# F1 = 0.985 vs. 0.158
# Precision = 0.971 vs. 0.086
# Recall = 0.998 vs. 0.934
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.650 vs. 0.059
# F1 = 0.662 vs. 0.079
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.274 vs. 0.048
# F1 = 0.338 vs. 0.101
# Precision = 0.261 vs. 0.053
# Recall = 0.481 vs. 0.896
# Minibatch Loss= 0.005423
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.097
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.996 vs. 0.100
# F1 = 0.986 vs. 0.178
# Precision = 0.976 vs. 0.098
# Recall = 0.997 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.648 vs. 0.058
# F1 = 0.659 vs. 0.079
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.272 vs. 0.052
# F1 = 0.333 vs. 0.099
# Precision = 0.263 vs. 0.052
# Recall = 0.452 vs. 0.961
# Minibatch Loss= 0.005828
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.090
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.996 vs. 0.095
# F1 = 0.991 vs. 0.177
# Precision = 0.989 vs. 0.098
# Recall = 0.994 vs. 0.945
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.644 vs. 0.059
# F1 = 0.659 vs. 0.077
# Accuracy = 0.897 vs. 0.056
# CHANGE DETECTION
# AUC = 0.276 vs. 0.054
# F1 = 0.339 vs. 0.102
# Precision = 0.272 vs. 0.055
# Recall = 0.449 vs. 0.706
# Minibatch Loss= 0.004963
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.095
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.108
# F1 = 0.993 vs. 0.193
# Precision = 0.991 vs. 0.107
# Recall = 0.996 vs. 0.957
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.643 vs. 0.059
# F1 = 0.656 vs. 0.079
# Accuracy = 0.898 vs. 0.056
# CHANGE DETECTION
# AUC = 0.274 vs. 0.051
# F1 = 0.337 vs. 0.097
# Precision = 0.282 vs. 0.051
# Recall = 0.418 vs. 1.000
# Minibatch Loss= 0.004433
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.095
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.114
# F1 = 0.996 vs. 0.195
# Precision = 0.993 vs. 0.111
# Recall = 1.000 vs. 0.799
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.641 vs. 0.059
# F1 = 0.656 vs. 0.081
# Accuracy = 0.899 vs. 0.056
# CHANGE DETECTION
# AUC = 0.274 vs. 0.051
# F1 = 0.337 vs. 0.097
# Precision = 0.248 vs. 0.051
# Recall = 0.525 vs. 1.000
# Minibatch Loss= 0.003976
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.091
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.098
# F1 = 0.998 vs. 0.177
# Precision = 0.997 vs. 0.097
# Recall = 0.998 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.638 vs. 0.058
# F1 = 0.656 vs. 0.079
# Accuracy = 0.899 vs. 0.056
# CHANGE DETECTION
# AUC = 0.273 vs. 0.052
# F1 = 0.337 vs. 0.097
# Precision = 0.278 vs. 0.052
# Recall = 0.429 vs. 0.714
# Minibatch Loss= 0.003747
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.914 vs. 0.061
# F1 = 0.862 vs. 0.094
# Accuracy = 0.862 vs. 0.056
# CHANGE DETECTION
# AUC = 0.666 vs. 0.111
# F1 = 0.630 vs. 0.194
# Precision = 0.543 vs. 0.108
# Recall = 0.751 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.598 vs. 0.058
# F1 = 0.603 vs. 0.079
# Accuracy = 0.792 vs. 0.056
# CHANGE DETECTION
# AUC = 0.232 vs. 0.054
# F1 = 0.320 vs. 0.100
# Precision = 0.243 vs. 0.053
# Recall = 0.468 vs. 0.745
# Minibatch Loss= 0.164781
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.061
# F1 = 0.965 vs. 0.094
# Accuracy = 0.978 vs. 0.056
# CHANGE DETECTION
# AUC = 0.880 vs. 0.105
# F1 = 0.810 vs. 0.188
# Precision = 0.786 vs. 0.104
# Recall = 0.836 vs. 0.982
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.697 vs. 0.059
# F1 = 0.680 vs. 0.081
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.309 vs. 0.053
# F1 = 0.390 vs. 0.097
# Precision = 0.347 vs. 0.052
# Recall = 0.447 vs. 0.862
# Minibatch Loss= 0.034366
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.061
# F1 = 0.983 vs. 0.091
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.947 vs. 0.102
# F1 = 0.894 vs. 0.180
# Precision = 0.852 vs. 0.099
# Recall = 0.941 vs. 0.971
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.684 vs. 0.060
# F1 = 0.671 vs. 0.079
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.304 vs. 0.048
# F1 = 0.379 vs. 0.097
# Precision = 0.315 vs. 0.051
# Recall = 0.475 vs. 0.927
# Minibatch Loss= 0.020586
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.063
# F1 = 0.994 vs. 0.096
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.980 vs. 0.104
# F1 = 0.944 vs. 0.188
# Precision = 0.926 vs. 0.104
# Recall = 0.964 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.678 vs. 0.059
# F1 = 0.669 vs. 0.080
# Accuracy = 0.885 vs. 0.056
# CHANGE DETECTION
# AUC = 0.301 vs. 0.052
# F1 = 0.376 vs. 0.097
# Precision = 0.335 vs. 0.051
# Recall = 0.429 vs. 0.990
# Minibatch Loss= 0.013987
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.997 vs. 0.091
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.989 vs. 0.092
# F1 = 0.965 vs. 0.167
# Precision = 0.955 vs. 0.091
# Recall = 0.976 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.669 vs. 0.059
# F1 = 0.665 vs. 0.083
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.298 vs. 0.052
# F1 = 0.369 vs. 0.098
# Precision = 0.332 vs. 0.052
# Recall = 0.416 vs. 0.756
# Minibatch Loss= 0.009208
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.998 vs. 0.093
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.102
# F1 = 0.982 vs. 0.187
# Precision = 0.966 vs. 0.103
# Recall = 0.998 vs. 0.989
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.658 vs. 0.059
# F1 = 0.656 vs. 0.081
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.296 vs. 0.053
# F1 = 0.360 vs. 0.099
# Precision = 0.316 vs. 0.053
# Recall = 0.418 vs. 0.852
# Minibatch Loss= 0.008008
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.998 vs. 0.094
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.995 vs. 0.089
# F1 = 0.987 vs. 0.168
# Precision = 0.978 vs. 0.092
# Recall = 0.997 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.649 vs. 0.059
# F1 = 0.654 vs. 0.081
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.294 vs. 0.054
# F1 = 0.349 vs. 0.097
# Precision = 0.279 vs. 0.072
# Recall = 0.465 vs. 0.148
# Minibatch Loss= 0.006342
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.096
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.097
# F1 = 0.990 vs. 0.187
# Precision = 0.987 vs. 0.103
# Recall = 0.993 vs. 0.987
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.647 vs. 0.059
# F1 = 0.652 vs. 0.083
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.293 vs. 0.055
# F1 = 0.350 vs. 0.097
# Precision = 0.335 vs. 0.053
# Recall = 0.366 vs. 0.582
# Minibatch Loss= 0.005409
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 0.999 vs. 0.094
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.097
# F1 = 0.997 vs. 0.184
# Precision = 0.994 vs. 0.103
# Recall = 1.000 vs. 0.874
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.641 vs. 0.058
# F1 = 0.650 vs. 0.079
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.290 vs. 0.052
# F1 = 0.345 vs. 0.097
# Precision = 0.314 vs. 0.051
# Recall = 0.382 vs. 1.000
# Minibatch Loss= 0.004303
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.094
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.101
# F1 = 0.992 vs. 0.172
# Precision = 0.990 vs. 0.095
# Recall = 0.995 vs. 0.867
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.643 vs. 0.059
# F1 = 0.652 vs. 0.082
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.287 vs. 0.055
# F1 = 0.344 vs. 0.105
# Precision = 0.337 vs. 0.068
# Recall = 0.351 vs. 0.236
# Minibatch Loss= 0.003980
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.091
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.104
# F1 = 0.998 vs. 0.182
# Precision = 0.997 vs. 0.100
# Recall = 1.000 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.641 vs. 0.059
# F1 = 0.653 vs. 0.084
# Accuracy = 0.895 vs. 0.056
# CHANGE DETECTION
# AUC = 0.289 vs. 0.051
# F1 = 0.345 vs. 0.101
# Precision = 0.315 vs. 0.054
# Recall = 0.382 vs. 0.808
# Minibatch Loss= 0.003921
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.093
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.094
# F1 = 1.000 vs. 0.173
# Precision = 1.000 vs. 0.095
# Recall = 1.000 vs. 0.951
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.638 vs. 0.059
# F1 = 0.649 vs. 0.082
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.287 vs. 0.055
# F1 = 0.346 vs. 0.099
# Precision = 0.322 vs. 0.054
# Recall = 0.374 vs. 0.540
# Minibatch Loss= 0.003176
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.088
# F1 = 0.999 vs. 0.172
# Precision = 0.998 vs. 0.094
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.635 vs. 0.058
# F1 = 0.647 vs. 0.080
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.284 vs. 0.049
# F1 = 0.342 vs. 0.098
# Precision = 0.312 vs. 0.053
# Recall = 0.379 vs. 0.579
# Minibatch Loss= 0.002966
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.090
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.096
# F1 = 0.999 vs. 0.163
# Precision = 0.998 vs. 0.090
# Recall = 1.000 vs. 0.907
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.631 vs. 0.059
# F1 = 0.647 vs. 0.082
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.283 vs. 0.051
# F1 = 0.343 vs. 0.098
# Precision = 0.299 vs. 0.054
# Recall = 0.403 vs. 0.532
# Minibatch Loss= 0.002328
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.096
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.088
# F1 = 1.000 vs. 0.157
# Precision = 1.000 vs. 0.085
# Recall = 1.000 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.630 vs. 0.060
# F1 = 0.643 vs. 0.080
# Accuracy = 0.895 vs. 0.056
# CHANGE DETECTION
# AUC = 0.281 vs. 0.048
# F1 = 0.339 vs. 0.097
# Precision = 0.296 vs. 0.051
# Recall = 0.397 vs. 0.956
# Minibatch Loss= 0.002084
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.092
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.103
# F1 = 1.000 vs. 0.173
# Precision = 1.000 vs. 0.098
# Recall = 1.000 vs. 0.725
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.630 vs. 0.059
# F1 = 0.645 vs. 0.081
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.279 vs. 0.048
# F1 = 0.340 vs. 0.097
# Precision = 0.303 vs. 0.051
# Recall = 0.387 vs. 0.966
# Minibatch Loss= 0.002123
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.091
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.090
# F1 = 0.998 vs. 0.168
# Precision = 0.998 vs. 0.092
# Recall = 0.998 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.628 vs. 0.059
# F1 = 0.643 vs. 0.083
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.277 vs. 0.055
# F1 = 0.346 vs. 0.097
# Precision = 0.306 vs. 0.051
# Recall = 0.397 vs. 0.896
# Minibatch Loss= 0.002164
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.088
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.085
# F1 = 0.999 vs. 0.156
# Precision = 0.998 vs. 0.084
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.626 vs. 0.059
# F1 = 0.641 vs. 0.084
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.278 vs. 0.051
# F1 = 0.342 vs. 0.099
# Precision = 0.300 vs. 0.056
# Recall = 0.397 vs. 0.403
# Minibatch Loss= 0.001832
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.986 vs. 0.063
# F1 = 0.960 vs. 0.093
# Accuracy = 0.944 vs. 0.056
# CHANGE DETECTION
# AUC = 0.919 vs. 0.099
# F1 = 0.840 vs. 0.188
# Precision = 0.807 vs. 0.105
# Recall = 0.875 vs. 0.932
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.691 vs. 0.060
# F1 = 0.680 vs. 0.080
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.298 vs. 0.053
# F1 = 0.372 vs. 0.101
# Precision = 0.324 vs. 0.062
# Recall = 0.436 vs. 0.278
# Minibatch Loss= 0.038251
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.059
# F1 = 0.997 vs. 0.088
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.090
# F1 = 0.983 vs. 0.160
# Precision = 0.981 vs. 0.089
# Recall = 0.985 vs. 0.768
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.681 vs. 0.059
# F1 = 0.677 vs. 0.080
# Accuracy = 0.900 vs. 0.056
# CHANGE DETECTION
# AUC = 0.309 vs. 0.053
# F1 = 0.380 vs. 0.098
# Precision = 0.356 vs. 0.053
# Recall = 0.408 vs. 0.605
# Minibatch Loss= 0.005790
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.092
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.092
# F1 = 0.998 vs. 0.167
# Precision = 0.997 vs. 0.091
# Recall = 1.000 vs. 0.977
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.665 vs. 0.059
# F1 = 0.665 vs. 0.080
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.301 vs. 0.046
# F1 = 0.372 vs. 0.097
# Precision = 0.328 vs. 0.051
# Recall = 0.429 vs. 0.925
# Minibatch Loss= 0.003326
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.095
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.109
# F1 = 0.998 vs. 0.196
# Precision = 0.997 vs. 0.112
# Recall = 1.000 vs. 0.788
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.658 vs. 0.058
# F1 = 0.664 vs. 0.077
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.297 vs. 0.050
# F1 = 0.364 vs. 0.097
# Precision = 0.334 vs. 0.051
# Recall = 0.400 vs. 0.987
# Minibatch Loss= 0.003185
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.093
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.090
# F1 = 1.000 vs. 0.175
# Precision = 1.000 vs. 0.096
# Recall = 1.000 vs. 0.985
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.651 vs. 0.059
# F1 = 0.664 vs. 0.082
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.296 vs. 0.049
# F1 = 0.362 vs. 0.097
# Precision = 0.332 vs. 0.051
# Recall = 0.397 vs. 0.992
# Minibatch Loss= 0.002201
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.096
# F1 = 0.999 vs. 0.172
# Precision = 0.998 vs. 0.094
# Recall = 1.000 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.648 vs. 0.058
# F1 = 0.660 vs. 0.079
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.296 vs. 0.051
# F1 = 0.366 vs. 0.096
# Precision = 0.327 vs. 0.051
# Recall = 0.416 vs. 1.000
# Minibatch Loss= 0.002036
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.091
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.091
# F1 = 1.000 vs. 0.161
# Precision = 1.000 vs. 0.092
# Recall = 1.000 vs. 0.658
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.647 vs. 0.059
# F1 = 0.661 vs. 0.082
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.293 vs. 0.055
# F1 = 0.364 vs. 0.096
# Precision = 0.328 vs. 0.051
# Recall = 0.410 vs. 0.997
# Minibatch Loss= 0.001504
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.095
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.099
# F1 = 1.000 vs. 0.181
# Precision = 1.000 vs. 0.099
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.644 vs. 0.058
# F1 = 0.657 vs. 0.077
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.294 vs. 0.056
# F1 = 0.360 vs. 0.099
# Precision = 0.322 vs. 0.052
# Recall = 0.408 vs. 0.888
# Minibatch Loss= 0.001807
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.091
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.083
# F1 = 1.000 vs. 0.154
# Precision = 1.000 vs. 0.084
# Recall = 1.000 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.641 vs. 0.059
# F1 = 0.654 vs. 0.080
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.293 vs. 0.051
# F1 = 0.357 vs. 0.097
# Precision = 0.311 vs. 0.052
# Recall = 0.418 vs. 0.655
# Minibatch Loss= 0.001433
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.088
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.081
# F1 = 0.999 vs. 0.150
# Precision = 0.998 vs. 0.081
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.643 vs. 0.059
# F1 = 0.654 vs. 0.077
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.293 vs. 0.050
# F1 = 0.356 vs. 0.099
# Precision = 0.310 vs. 0.053
# Recall = 0.418 vs. 0.764
# Minibatch Loss= 0.001189
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.090
# F1 = 1.000 vs. 0.161
# Precision = 1.000 vs. 0.088
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.641 vs. 0.060
# F1 = 0.652 vs. 0.084
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.291 vs. 0.049
# F1 = 0.359 vs. 0.098
# Precision = 0.326 vs. 0.051
# Recall = 0.400 vs. 0.977
# Minibatch Loss= 0.001192
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.095
# F1 = 1.000 vs. 0.170
# Precision = 1.000 vs. 0.093
# Recall = 1.000 vs. 0.971
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.638 vs. 0.058
# F1 = 0.653 vs. 0.080
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.290 vs. 0.050
# F1 = 0.358 vs. 0.100
# Precision = 0.332 vs. 0.053
# Recall = 0.390 vs. 0.953
# Minibatch Loss= 0.001208
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.094
# F1 = 1.000 vs. 0.181
# Precision = 1.000 vs. 0.100
# Recall = 1.000 vs. 0.954
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.636 vs. 0.058
# F1 = 0.652 vs. 0.078
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.291 vs. 0.050
# F1 = 0.359 vs. 0.097
# Precision = 0.329 vs. 0.051
# Recall = 0.395 vs. 0.982
# Minibatch Loss= 0.001030
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.087
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.153
# Precision = 1.000 vs. 0.083
# Recall = 1.000 vs. 0.977
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.630 vs. 0.059
# F1 = 0.651 vs. 0.080
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.290 vs. 0.052
# F1 = 0.356 vs. 0.098
# Precision = 0.325 vs. 0.052
# Recall = 0.395 vs. 0.901
# Minibatch Loss= 0.000904
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.093
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.096
# F1 = 1.000 vs. 0.171
# Precision = 1.000 vs. 0.095
# Recall = 1.000 vs. 0.861
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.631 vs. 0.059
# F1 = 0.651 vs. 0.079
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.286 vs. 0.051
# F1 = 0.352 vs. 0.099
# Precision = 0.314 vs. 0.053
# Recall = 0.400 vs. 0.683
# Minibatch Loss= 0.000871
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.064
# F1 = 1.000 vs. 0.095
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.100
# F1 = 1.000 vs. 0.180
# Precision = 1.000 vs. 0.099
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.633 vs. 0.059
# F1 = 0.649 vs. 0.081
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.288 vs. 0.055
# F1 = 0.350 vs. 0.102
# Precision = 0.317 vs. 0.059
# Recall = 0.392 vs. 0.379
# Minibatch Loss= 0.000877
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.095
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.104
# F1 = 1.000 vs. 0.192
# Precision = 1.000 vs. 0.106
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.633 vs. 0.060
# F1 = 0.650 vs. 0.083
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.288 vs. 0.056
# F1 = 0.349 vs. 0.098
# Precision = 0.309 vs. 0.054
# Recall = 0.403 vs. 0.527
# Minibatch Loss= 0.000808
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.082
# F1 = 1.000 vs. 0.154
# Precision = 1.000 vs. 0.084
# Recall = 1.000 vs. 0.983
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.634 vs. 0.059
# F1 = 0.648 vs. 0.082
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.285 vs. 0.054
# F1 = 0.346 vs. 0.098
# Precision = 0.274 vs. 0.052
# Recall = 0.470 vs. 0.873
# Minibatch Loss= 0.000706
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.087
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.087
# F1 = 1.000 vs. 0.154
# Precision = 1.000 vs. 0.084
# Recall = 1.000 vs. 0.981
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.626 vs. 0.059
# F1 = 0.648 vs. 0.083
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.284 vs. 0.055
# F1 = 0.348 vs. 0.101
# Precision = 0.276 vs. 0.060
# Recall = 0.470 vs. 0.332
# Minibatch Loss= 0.000642
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.950 vs. 0.061
# F1 = 0.895 vs. 0.090
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.681 vs. 0.084
# F1 = 0.647 vs. 0.158
# Precision = 0.579 vs. 0.086
# Recall = 0.733 vs. 0.989
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.624 vs. 0.059
# F1 = 0.633 vs. 0.086
# Accuracy = 0.826 vs. 0.056
# CHANGE DETECTION
# AUC = 0.278 vs. 0.054
# F1 = 0.350 vs. 0.100
# Precision = 0.285 vs. 0.062
# Recall = 0.452 vs. 0.257
# Minibatch Loss= 0.088607
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.061
# F1 = 0.971 vs. 0.089
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.891 vs. 0.082
# F1 = 0.833 vs. 0.163
# Precision = 0.768 vs. 0.089
# Recall = 0.911 vs. 0.970
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.695 vs. 0.059
# F1 = 0.688 vs. 0.081
# Accuracy = 0.899 vs. 0.056
# CHANGE DETECTION
# AUC = 0.331 vs. 0.052
# F1 = 0.392 vs. 0.098
# Precision = 0.315 vs. 0.052
# Recall = 0.517 vs. 0.787
# Minibatch Loss= 0.024806
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.062
# F1 = 0.987 vs. 0.092
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 0.969 vs. 0.091
# F1 = 0.929 vs. 0.161
# Precision = 0.908 vs. 0.088
# Recall = 0.952 vs. 0.986
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.686 vs. 0.059
# F1 = 0.677 vs. 0.079
# Accuracy = 0.898 vs. 0.056
# CHANGE DETECTION
# AUC = 0.318 vs. 0.048
# F1 = 0.395 vs. 0.097
# Precision = 0.374 vs. 0.051
# Recall = 0.418 vs. 0.990
# Minibatch Loss= 0.013395
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.994 vs. 0.090
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.986 vs. 0.092
# F1 = 0.964 vs. 0.159
# Precision = 0.951 vs. 0.087
# Recall = 0.978 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.677 vs. 0.059
# F1 = 0.672 vs. 0.083
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.311 vs. 0.052
# F1 = 0.394 vs. 0.098
# Precision = 0.336 vs. 0.052
# Recall = 0.475 vs. 0.969
# Minibatch Loss= 0.009352
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 0.999 vs. 0.087
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.076
# F1 = 0.984 vs. 0.153
# Precision = 0.976 vs. 0.083
# Recall = 0.992 vs. 0.983
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.670 vs. 0.060
# F1 = 0.668 vs. 0.084
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.310 vs. 0.052
# F1 = 0.387 vs. 0.099
# Precision = 0.330 vs. 0.053
# Recall = 0.468 vs. 0.860
# Minibatch Loss= 0.005229
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.091
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.098
# F1 = 0.996 vs. 0.185
# Precision = 0.992 vs. 0.103
# Recall = 1.000 vs. 0.909
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.666 vs. 0.059
# F1 = 0.670 vs. 0.082
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.310 vs. 0.053
# F1 = 0.378 vs. 0.100
# Precision = 0.356 vs. 0.053
# Recall = 0.403 vs. 0.881
# Minibatch Loss= 0.004715
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.095
# F1 = 0.996 vs. 0.173
# Precision = 0.993 vs. 0.096
# Recall = 0.998 vs. 0.852
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.661 vs. 0.059
# F1 = 0.667 vs. 0.086
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# ...
# Precision = 0.343 vs. 0.053
# Recall = 0.462 vs. 0.945
# Minibatch Loss= 0.000563
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.088
# F1 = 1.000 vs. 0.160
# Precision = 1.000 vs. 0.087
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.676 vs. 0.060
# F1 = 0.683 vs. 0.082
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.325 vs. 0.055
# F1 = 0.394 vs. 0.097
# Precision = 0.346 vs. 0.051
# Recall = 0.457 vs. 0.974
# Minibatch Loss= 0.000541
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.086
# F1 = 1.000 vs. 0.167
# Precision = 1.000 vs. 0.091
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.672 vs. 0.059
# F1 = 0.682 vs. 0.082
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.323 vs. 0.054
# F1 = 0.391 vs. 0.099
# Precision = 0.368 vs. 0.055
# Recall = 0.418 vs. 0.499
# Minibatch Loss= 0.000456
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.096
# F1 = 1.000 vs. 0.182
# Precision = 1.000 vs. 0.101
# Recall = 1.000 vs. 0.984
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.675 vs. 0.058
# F1 = 0.682 vs. 0.082
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.323 vs. 0.054
# F1 = 0.392 vs. 0.097
# Precision = 0.359 vs. 0.052
# Recall = 0.431 vs. 0.810
# Minibatch Loss= 0.000481
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.088
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.083
# F1 = 1.000 vs. 0.152
# Precision = 1.000 vs. 0.082
# Recall = 1.000 vs. 0.988
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.673 vs. 0.059
# F1 = 0.680 vs. 0.084
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.327 vs. 0.051
# F1 = 0.389 vs. 0.097
# Precision = 0.357 vs. 0.051
# Recall = 0.426 vs. 1.000
# Minibatch Loss= 0.000385
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.111
# F1 = 1.000 vs. 0.191
# Precision = 1.000 vs. 0.105
# Recall = 1.000 vs. 0.999
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.672 vs. 0.060
# F1 = 0.680 vs. 0.082
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.323 vs. 0.048
# F1 = 0.386 vs. 0.099
# Precision = 0.355 vs. 0.053
# Recall = 0.423 vs. 0.797
# Minibatch Loss= 0.000426
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.088
# F1 = 1.000 vs. 0.156
# Precision = 1.000 vs. 0.088
# Recall = 1.000 vs. 0.667
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.673 vs. 0.059
# F1 = 0.679 vs. 0.082
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.322 vs. 0.049
# F1 = 0.385 vs. 0.097
# Precision = 0.310 vs. 0.051
# Recall = 0.506 vs. 1.000
# Minibatch Loss= 0.000311
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.084
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.137
# Precision = 1.000 vs. 0.074
# Recall = 1.000 vs. 0.886
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.672 vs. 0.059
# F1 = 0.678 vs. 0.079
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.328 vs. 0.052
# F1 = 0.384 vs. 0.098
# Precision = 0.310 vs. 0.055
# Recall = 0.504 vs. 0.491
# Minibatch Loss= 0.000247
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.097
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.106
# F1 = 1.000 vs. 0.190
# Precision = 1.000 vs. 0.105
# Recall = 1.000 vs. 0.978
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.671 vs. 0.058
# F1 = 0.677 vs. 0.081
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.325 vs. 0.058
# F1 = 0.383 vs. 0.101
# Precision = 0.305 vs. 0.059
# Recall = 0.517 vs. 0.351
# Minibatch Loss= 0.000319
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.088
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.084
# F1 = 1.000 vs. 0.162
# Precision = 1.000 vs. 0.092
# Recall = 1.000 vs. 0.675
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.670 vs. 0.058
# F1 = 0.676 vs. 0.077
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.330 vs. 0.050
# F1 = 0.383 vs. 0.097
# Precision = 0.367 vs. 0.051
# Recall = 0.400 vs. 0.964
# Minibatch Loss= 0.000245
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.102
# F1 = 1.000 vs. 0.183
# Precision = 1.000 vs. 0.101
# Recall = 1.000 vs. 0.951
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.669 vs. 0.059
# F1 = 0.675 vs. 0.082
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.329 vs. 0.050
# F1 = 0.383 vs. 0.099
# Precision = 0.367 vs. 0.053
# Recall = 0.400 vs. 0.834
# Minibatch Loss= 0.000239
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.085
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.086
# F1 = 1.000 vs. 0.160
# Precision = 1.000 vs. 0.089
# Recall = 1.000 vs. 0.802
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.667 vs. 0.059
# F1 = 0.674 vs. 0.079
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.325 vs. 0.050
# F1 = 0.381 vs. 0.097
# Precision = 0.366 vs. 0.052
# Recall = 0.397 vs. 0.818
# Minibatch Loss= 0.000222
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.085
# F1 = 1.000 vs. 0.166
# Precision = 1.000 vs. 0.090
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.665 vs. 0.059
# F1 = 0.673 vs. 0.081
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.327 vs. 0.052
# F1 = 0.381 vs. 0.100
# Precision = 0.305 vs. 0.053
# Recall = 0.506 vs. 0.886
# Minibatch Loss= 0.000202
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.094
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.095
# F1 = 1.000 vs. 0.176
# Precision = 1.000 vs. 0.096
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.664 vs. 0.058
# F1 = 0.673 vs. 0.078
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.326 vs. 0.051
# F1 = 0.381 vs. 0.097
# Precision = 0.308 vs. 0.051
# Recall = 0.501 vs. 0.966
# Minibatch Loss= 0.000199
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.103
# F1 = 1.000 vs. 0.177
# Precision = 1.000 vs. 0.099
# Recall = 1.000 vs. 0.880
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.664 vs. 0.059
# F1 = 0.672 vs. 0.080
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.325 vs. 0.051
# F1 = 0.381 vs. 0.097
# Precision = 0.309 vs. 0.051
# Recall = 0.496 vs. 0.982
# Minibatch Loss= 0.000191
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.079
# F1 = 1.000 vs. 0.151
# Precision = 1.000 vs. 0.082
# Recall = 1.000 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.661 vs. 0.058
# F1 = 0.671 vs. 0.077
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.327 vs. 0.056
# F1 = 0.381 vs. 0.101
# Precision = 0.307 vs. 0.054
# Recall = 0.501 vs. 0.800
# Minibatch Loss= 0.000162
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.093
# F1 = 1.000 vs. 0.171
# Precision = 1.000 vs. 0.094
# Recall = 1.000 vs. 0.939
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.662 vs. 0.058
# F1 = 0.671 vs. 0.080
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.325 vs. 0.051
# F1 = 0.381 vs. 0.098
# Precision = 0.307 vs. 0.052
# Recall = 0.501 vs. 0.764
# Minibatch Loss= 0.000166
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.108
# F1 = 1.000 vs. 0.185
# Precision = 1.000 vs. 0.103
# Recall = 1.000 vs. 0.921
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.663 vs. 0.058
# F1 = 0.670 vs. 0.079
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.326 vs. 0.054
# F1 = 0.379 vs. 0.101
# Precision = 0.374 vs. 0.055
# Recall = 0.384 vs. 0.644
# Minibatch Loss= 0.000168
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.094
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.117
# F1 = 1.000 vs. 0.201
# Precision = 1.000 vs. 0.117
# Recall = 1.000 vs. 0.719
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.663 vs. 0.059
# F1 = 0.670 vs. 0.080
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.328 vs. 0.050
# F1 = 0.378 vs. 0.097
# Precision = 0.295 vs. 0.051
# Recall = 0.527 vs. 0.995
# Minibatch Loss= 0.000154
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.084
# F1 = 1.000 vs. 0.160
# Precision = 1.000 vs. 0.088
# Recall = 1.000 vs. 0.860
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.662 vs. 0.059
# F1 = 0.669 vs. 0.082
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.327 vs. 0.054
# F1 = 0.377 vs. 0.097
# Precision = 0.297 vs. 0.051
# Recall = 0.517 vs. 1.000
# Minibatch Loss= 0.000145
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.089
# F1 = 1.000 vs. 0.161
# Precision = 1.000 vs. 0.089
# Recall = 1.000 vs. 0.892
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.664 vs. 0.058
# F1 = 0.669 vs. 0.078
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.323 vs. 0.053
# F1 = 0.376 vs. 0.101
# Precision = 0.296 vs. 0.054
# Recall = 0.514 vs. 0.701
# Minibatch Loss= 0.000150
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.094
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.089
# F1 = 1.000 vs. 0.165
# Precision = 1.000 vs. 0.090
# Recall = 1.000 vs. 0.949
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.656 vs. 0.058
# F1 = 0.669 vs. 0.082
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.327 vs. 0.053
# F1 = 0.375 vs. 0.097
# Precision = 0.294 vs. 0.051
# Recall = 0.519 vs. 0.943
# Minibatch Loss= 0.000124
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.087
# F1 = 1.000 vs. 0.163
# Precision = 1.000 vs. 0.089
# Recall = 1.000 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.661 vs. 0.061
# F1 = 0.669 vs. 0.084
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.325 vs. 0.046
# F1 = 0.377 vs. 0.097
# Precision = 0.285 vs. 0.051
# Recall = 0.556 vs. 0.951
# Minibatch Loss= 0.000128
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.092
# F1 = 1.000 vs. 0.173
# Precision = 1.000 vs. 0.095
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.657 vs. 0.059
# F1 = 0.669 vs. 0.080
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.330 vs. 0.050
# F1 = 0.377 vs. 0.097
# Precision = 0.292 vs. 0.051
# Recall = 0.532 vs. 1.000
# Minibatch Loss= 0.000132
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.095
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.097
# F1 = 1.000 vs. 0.176
# Precision = 1.000 vs. 0.097
# Recall = 1.000 vs. 0.936
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.658 vs. 0.059
# F1 = 0.669 vs. 0.082
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.325 vs. 0.050
# F1 = 0.377 vs. 0.102
# Precision = 0.284 vs. 0.054
# Recall = 0.558 vs. 0.862
# Minibatch Loss= 0.000125
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.094
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.087
# F1 = 1.000 vs. 0.168
# Precision = 1.000 vs. 0.092
# Recall = 1.000 vs. 0.990
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.659 vs. 0.058
# F1 = 0.669 vs. 0.078
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.325 vs. 0.053
# F1 = 0.376 vs. 0.097
# Precision = 0.285 vs. 0.052
# Recall = 0.553 vs. 0.803
# Minibatch Loss= 0.000114
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.086
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.086
# F1 = 1.000 vs. 0.162
# Precision = 1.000 vs. 0.089
# Recall = 1.000 vs. 0.944
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.656 vs. 0.059
# F1 = 0.669 vs. 0.079
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.326 vs. 0.050
# F1 = 0.378 vs. 0.100
# Precision = 0.287 vs. 0.054
# Recall = 0.553 vs. 0.678
# Minibatch Loss= 0.000094
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.100
# F1 = 1.000 vs. 0.181
# Precision = 1.000 vs. 0.099
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.660 vs. 0.058
# F1 = 0.668 vs. 0.081
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.051
# F1 = 0.377 vs. 0.097
# Precision = 0.285 vs. 0.051
# Recall = 0.556 vs. 0.979
# Minibatch Loss= 0.000110
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.088
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.095
# F1 = 1.000 vs. 0.158
# Precision = 1.000 vs. 0.095
# Recall = 1.000 vs. 0.470
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.660 vs. 0.058
# F1 = 0.668 vs. 0.082
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.322 vs. 0.050
# F1 = 0.377 vs. 0.099
# Precision = 0.291 vs. 0.054
# Recall = 0.535 vs. 0.600
# Minibatch Loss= 0.000094
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.101
# F1 = 1.000 vs. 0.172
# Precision = 1.000 vs. 0.094
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.658 vs. 0.059
# F1 = 0.669 vs. 0.082
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.325 vs. 0.055
# F1 = 0.376 vs. 0.096
# Precision = 0.282 vs. 0.069
# Recall = 0.564 vs. 0.158
# Minibatch Loss= 0.000090
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.084
# F1 = 1.000 vs. 0.154
# Precision = 1.000 vs. 0.085
# Recall = 1.000 vs. 0.773
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.655 vs. 0.059
# F1 = 0.668 vs. 0.081
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.320 vs. 0.056
# F1 = 0.375 vs. 0.100
# Precision = 0.287 vs. 0.055
# Recall = 0.540 vs. 0.532
# Minibatch Loss= 0.000063
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.091
# F1 = 1.000 vs. 0.159
# Precision = 1.000 vs. 0.086
# Recall = 1.000 vs. 0.974
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.655 vs. 0.059
# F1 = 0.668 vs. 0.079
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.328 vs. 0.050
# F1 = 0.375 vs. 0.099
# Precision = 0.286 vs. 0.052
# Recall = 0.545 vs. 0.881
# Minibatch Loss= 0.000079
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.096
# F1 = 1.000 vs. 0.177
# Precision = 1.000 vs. 0.097
# Recall = 1.000 vs. 0.974
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.653 vs. 0.059
# F1 = 0.668 vs. 0.081
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.319 vs. 0.052
# F1 = 0.375 vs. 0.097
# Precision = 0.290 vs. 0.051
# Recall = 0.532 vs. 0.917
# Minibatch Loss= 0.000079
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.097
# F1 = 1.000 vs. 0.176
# Precision = 1.000 vs. 0.097
# Recall = 1.000 vs. 0.967
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.655 vs. 0.059
# F1 = 0.668 vs. 0.083
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.327 vs. 0.055
# F1 = 0.375 vs. 0.097
# Precision = 0.299 vs. 0.051
# Recall = 0.504 vs. 0.997
# Minibatch Loss= 0.000076
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.088
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.087
# F1 = 1.000 vs. 0.151
# Precision = 1.000 vs. 0.083
# Recall = 1.000 vs. 0.868
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.652 vs. 0.058
# F1 = 0.668 vs. 0.079
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.321 vs. 0.050
# F1 = 0.375 vs. 0.100
# Precision = 0.287 vs. 0.054
# Recall = 0.540 vs. 0.727
# Minibatch Loss= 0.000068
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../../model/RCNN_Wmultitask_16_opp/RCNN_Wmultitask_16_opp-20000'

# %%
#load the model
#saver = tf.train.Saver()
#saver.restore(sess, "../model" + "/CNN7002_Gleam" + "/CNN7002_Gleam")
#saver.restore(sess, '../model/CNN7002_Gleam/CNN7002_Gleam-10000')

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# ACTIVITY RECOGNITION
# AUC = 0.656 vs. 0.059
# F1 = 0.667 vs. 0.082
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.323 vs. 0.050
# F1 = 0.372 vs. 0.096
# Precision = 0.281 vs. 0.051
# Recall = 0.553 vs. 0.992

# %%
out = nn_eval.deploy (model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
#probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../../poc/poc'+exp_name+'.mat', {'poc':out[:,:,-1]})

# %%
1
# Out:
# 1
